# %%
import os
import json
import pandas as  pd
import psycopg2
import streamlit as st
import plotly.express as px

# %%
#aggre_transaction

path1="C:/Users/vigne/Desktop/project 2/phonepe/pulse/data/aggregated/transaction/country/india/state/"
ATL= os.listdir(path1)


columns1={"States":[], "Years":[],"Quarter":[], "Transaction_type":[], "Transaction_count":[], "Transaction_amount":[]}

for state in ATL:
    current_state=path1+state+"/"
    AYL=os.listdir(current_state)
    
    for year in AYL:
        current_year=current_state+year+"/"
        AFL=os.listdir(current_year)
        
        for file in AFL:
            cursor_file=current_year+file
            data=open(cursor_file,"r")

            A=json.load(data)

            for i in A["data"]["transactionData"]:
                name=i["name"]
                count=i["paymentInstruments"][0]["count"]
                amount=i["paymentInstruments"][0]["amount"]
                columns1["Transaction_type"].append(name)
                columns1["Transaction_count"].append(count)
                columns1["Transaction_amount"].append(amount)
                columns1["States"].append(state)
                columns1["Years"].append(year)
                columns1["Quarter"].append(int(file.strip(".json")))

# %%
aggre_transaction=pd.DataFrame(columns1)

# %%
aggre_transaction
# Out:
#                          States Years  Quarter          Transaction_type  \
# 0     andaman-&-nicobar-islands  2018        1  Recharge & bill payments
# 1     andaman-&-nicobar-islands  2018        1     Peer-to-peer payments
# 2     andaman-&-nicobar-islands  2018        1         Merchant payments
# 3     andaman-&-nicobar-islands  2018        1        Financial Services
# 4     andaman-&-nicobar-islands  2018        1                    Others
# ...                         ...   ...      ...                       ...
# 4129                west-bengal  2023        3         Merchant payments
# 4130                west-bengal  2023        3     Peer-to-peer payments
# 4131                west-bengal  2023        3  Recharge & bill payments
# 4132                west-bengal  2023        3        Financial Services
# 4133                west-bengal  2023        3                    Others
#
#       Transaction_count  Transaction_amount
# 0                  4200        1.845307e+06
# ...

# %%
#aggr_insurance
path2="C:/Users/vigne/Desktop/project 2/phonepe/pulse/data/aggregated/insurance/country/india/state/"
AIL= os.listdir(path2)

columns2={"States":[], "Years":[],"Quarter":[], "Transaction_type":[], "Transaction_count":[], "Transaction_amount":[]}


for state in AIL:
    current_state=path2+state+"/"
    AYL=os.listdir(current_state)

    for year in AYL:
        current_year=current_state+year+"/"
        AFL=os.listdir(current_year)
        
        for file in AFL:
            cursor_file=current_year+file
            data=open(cursor_file,"r")

            B=json.load(data)

            for i in B["data"]["transactionData"]:
                name=i["name"]
                count=i["paymentInstruments"][0]["count"]
                amount=i["paymentInstruments"][0]["amount"]
                columns2["Transaction_type"].append(name)
                columns2["Transaction_count"].append(count)
                columns2["Transaction_amount"].append(amount)
                columns2["States"].append(state)
                columns2["Years"].append(year)
                columns2["Quarter"].append(int(file.strip(".json")))

# %%
aggre_insurance=pd.DataFrame(columns2)

# %%
aggre_insurance
# Out:
#                         States Years  Quarter Transaction_type  \
# 0    andaman-&-nicobar-islands  2020        2        Insurance
# 1    andaman-&-nicobar-islands  2020        3        Insurance
# 2    andaman-&-nicobar-islands  2020        4        Insurance
# 3    andaman-&-nicobar-islands  2021        1        Insurance
# 4    andaman-&-nicobar-islands  2021        2        Insurance
# ..                         ...   ...      ...              ...
# 497                west-bengal  2022        3        Insurance
# 498                west-bengal  2022        4        Insurance
# 499                west-bengal  2023        1        Insurance
# 500                west-bengal  2023        2        Insurance
# 501                west-bengal  2023        3        Insurance
#
#      Transaction_count  Transaction_amount
# 0                    6              1360.0
# 1                   41             15380.0
# 2                  124            157975.0
# ...

# %%
B["data"]["transactionData"][0]["paymentInstruments"][0]["amount"]
# Out:
# 76359312.0

# %%
#Aggr_User
path3="C:/Users/vigne/Desktop/project 2/phonepe/pulse/data/aggregated/user/country/india/state/"
AUL= os.listdir(path3)

columns3={"States":[], "Years":[],"Quarter":[], "Device_brand":[], "Device_count":[], "Percentage":[]}

for state in AUL:
    current_state=path3+state+"/"
    AYL=os.listdir(current_state)

    for year in AYL:
        current_year=current_state+year+"/"
        AFL=os.listdir(current_year)
        
        for file in AFL:
            cursor_file=current_year+file
            data=open(cursor_file,"r")

            C=json.load(data)
            try:

                for i in C["data"]["usersByDevice"]:
                    brand=i["brand"]
                    count=i["count"]
                    percentage=i["percentage"]
                    columns3["Device_brand"].append(brand)
                    columns3["Device_count"].append(count)
                    columns3["Percentage"].append(percentage)
                    columns3["States"].append(state)
                    columns3["Years"].append(year)
                    columns3["Quarter"].append(int(file.strip(".json")))
            except:
                pass

# %%
aggre_user=pd.DataFrame(columns3)

# %%
aggre_user
# Out:
#                          States Years  Quarter Device_brand  Device_count  \
# 0     andaman-&-nicobar-islands  2018        1       Xiaomi          1665
# 1     andaman-&-nicobar-islands  2018        1      Samsung          1445
# 2     andaman-&-nicobar-islands  2018        1         Vivo           982
# 3     andaman-&-nicobar-islands  2018        1         Oppo           501
# 4     andaman-&-nicobar-islands  2018        1      OnePlus           332
# ...                         ...   ...      ...          ...           ...
# 6727                west-bengal  2022        1       Lenovo        330017
# 6728                west-bengal  2022        1      Infinix        284678
# 6729                west-bengal  2022        1         Asus        280347
# 6730                west-bengal  2022        1        Apple        277752
# 6731                west-bengal  2022        1       Others       2196334
#
#       Percentage
# 0       0.247033
# 1       0.214392
# 2       0.145697
# ...

# %%
#Map_Transaction 
path4="C:/Users/vigne/Desktop/project 2/phonepe/pulse/data/map/transaction/hover/country/india/state/"
MTL= os.listdir(path4)

columns4={"States":[], "Years":[],"Quarter":[], "District_name":[], "Total_count":[], "Total_amount":[]}

for state in MTL:
    current_state=path4+state+"/"
    AYL=os.listdir(current_state)

    for year in AYL:
        current_year=current_state+year+"/"
        AFL=os.listdir(current_year)
        
        for file in AFL:
            cursor_file=current_year+file
            data=open(cursor_file,"r")

            D=json.load(data)
            
            for i in D["data"]["hoverDataList"]:
                    name=i["name"]
                    count=i["metric"][0]["count"]
                    amount=i["metric"][0]["amount"]
                    columns4["District_name"].append(name)
                    columns4["Total_count"].append(count)
                    columns4["Total_amount"].append(amount)
                    columns4["States"].append(state)
                    columns4["Years"].append(year)
                    columns4["Quarter"].append(int(file.strip(".json")))

# %%
D
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'hoverDataList': [{'name': 'south twenty four parganas district',
#     'metric': [{'type': 'TOTAL', 'count': 38719555, 'amount': 71124947936.0}]},
#    {'name': 'purba bardhaman district',
#     'metric': [{'type': 'TOTAL', 'count': 22072496, 'amount': 40249779056.0}]},
#    {'name': 'uttar dinajpur district',
#     'metric': [{'type': 'TOTAL', 'count': 17228585, 'amount': 31108601762.0}]},
#    {'name': 'kalimpong district',
#     'metric': [{'type': 'TOTAL', 'count': 861395, 'amount': 1489802436.0}]},
#    {'name': 'murshidabad district',
#     'metric': [{'type': 'TOTAL', 'count': 41360216, 'amount': 85165951696.0}]},
#    {'name': 'paschim medinipur district',
#     'metric': [{'type': 'TOTAL', 'count': 30418455, 'amount': 50431768074.0}]},
#    {'name': 'dakshin dinajpur district',
#     'metric': [{'type': 'TOTAL', 'count': 5956574, 'amount': 10882569492.0}]},
#    {'name': 'jalpaiguri district',
# ...

# %%
map_taransaction=pd.DataFrame(columns4)

# %%
map_taransaction
# Out:
#                           States Years  Quarter  \
# 0      andaman-&-nicobar-islands  2018        1
# 1      andaman-&-nicobar-islands  2018        1
# 2      andaman-&-nicobar-islands  2018        1
# 3      andaman-&-nicobar-islands  2018        2
# 4      andaman-&-nicobar-islands  2018        2
# ...                          ...   ...      ...
# 16827                west-bengal  2023        3
# 16828                west-bengal  2023        3
# 16829                west-bengal  2023        3
# 16830                west-bengal  2023        3
# 16831                west-bengal  2023        3
#
#                            District_name  Total_count  Total_amount
# 0      north and middle andaman district          442  9.316631e+05
# 1                 south andaman district         5688  1.256025e+07
# 2                      nicobars district          528  1.139849e+06
# 3      north and middle andaman district          825  1.317863e+06
# ...

# %%
#Map_user
path5="C:/Users/vigne/Desktop/project 2/phonepe/pulse/data/map/user/hover/country/india/state/"
MUL= os.listdir(path5)

columns5={"States":[], "Years":[],"Quarter":[], "District_name":[], "RegisteredUsers":[], "AppOpens":[]}

for state in MUL:
    current_state=path5+state+"/"
    AYL=os.listdir(current_state)

    for year in AYL:
        current_year=current_state+year+"/"
        AFL=os.listdir(current_year)
        
        for file in AFL:
            cursor_file=current_year+file
            data=open(cursor_file,"r")

            E=json.load(data)
            
            for i in E["data"]["hoverData"].items():
                district=i[0]
                registeredUsers=i[1]["registeredUsers"]
                appOpens=i[1]["appOpens"]
                columns5["District_name"].append(district)
                columns5["RegisteredUsers"].append(registeredUsers)
                columns5["AppOpens"].append(appOpens)
                columns5["States"].append(state)
                columns5["Years"].append(year)
                columns5["Quarter"].append(int(file.strip(".json")))

# %%
E
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'hoverData': {'south twenty four parganas district': {'registeredUsers': 2074469,
#     'appOpens': 36106296},
#    'purba bardhaman district': {'registeredUsers': 1272153,
#     'appOpens': 13425281},
#    'uttar dinajpur district': {'registeredUsers': 659711,
#     'appOpens': 30979165},
#    'kalimpong district': {'registeredUsers': 60803, 'appOpens': 12163745},
#    'murshidabad district': {'registeredUsers': 2023550, 'appOpens': 22637926},
#    'paschim medinipur district': {'registeredUsers': 1384076,
#     'appOpens': 27253598},
#    'dakshin dinajpur district': {'registeredUsers': 468842,
#     'appOpens': 11036806},
#    'jalpaiguri district': {'registeredUsers': 427529, 'appOpens': 27526284},
#    'purulia district': {'registeredUsers': 711605, 'appOpens': 40151644},
#    'north twenty four parganas district': {'registeredUsers': 4241525,
#     'appOpens': 15161063},
# ...

# %%
map_user=pd.DataFrame(columns5)

# %%
map_user
# Out:
#                           States Years  Quarter  \
# 0      andaman-&-nicobar-islands  2018        1
# 1      andaman-&-nicobar-islands  2018        1
# 2      andaman-&-nicobar-islands  2018        1
# 3      andaman-&-nicobar-islands  2018        2
# 4      andaman-&-nicobar-islands  2018        2
# ...                          ...   ...      ...
# 16831                west-bengal  2023        3
# 16832                west-bengal  2023        3
# 16833                west-bengal  2023        3
# 16834                west-bengal  2023        3
# 16835                west-bengal  2023        3
#
#                            District_name  RegisteredUsers  AppOpens
# 0      north and middle andaman district              632         0
# 1                 south andaman district             5846         0
# 2                      nicobars district              262         0
# 3      north and middle andaman district              911         0
# ...

# %%
for i in E["data"]["hoverData"].items():
    #print(i[0])
    #print(i[1]["registeredUsers"])
    print(i[1]["appOpens"])
# Out:
# 36106296
# 13425281
# 30979165
# 12163745
# 22637926
# 27253598
# 11036806
# 27526284
# 40151644
# 15161063
# 30550117
# 15380154
# 7720866
# 6860509
# 6895145
# 35359585
# 20820021
# 13439780
# 12674328
# 18961683
# 18593769
# 28020285
# 21732323

# %%
#Map_Insurance
path6="C:/Users/vigne/Desktop/project 2/phonepe/pulse/data/map/insurance/hover/country/india/state/"
MIL= os.listdir(path6)

columns6={"States":[], "Years":[],"Quarter":[], "District_name":[], "Total_count":[], "Total_amount":[]}

for state in MIL:
    current_state=path6+state+"/"
    AYL=os.listdir(current_state)

    for year in AYL:
        current_year=current_state+year+"/"
        AFL=os.listdir(current_year)
        
        for file in AFL:
            cursor_file=current_year+file
            data=open(cursor_file,"r")

            F=json.load(data)
            
            for i in F["data"]["hoverDataList"]:
                    name=i["name"]
                    count=i["metric"][0]["count"]
                    amount=i["metric"][0]["amount"]
                    columns6["District_name"].append(name)
                    columns6["Total_count"].append(count)
                    columns6["Total_amount"].append(amount)
                    columns6["States"].append(state)
                    columns6["Years"].append(year)
                    columns6["Quarter"].append(int(file.strip(".json")))

# %%
map_insurance=pd.DataFrame(columns6)

# %%
map_insurance
# Out:
#                           States Years  Quarter  \
# 0      andaman-&-nicobar-islands  2020        2
# 1      andaman-&-nicobar-islands  2020        2
# 2      andaman-&-nicobar-islands  2020        3
# 3      andaman-&-nicobar-islands  2020        3
# 4      andaman-&-nicobar-islands  2020        3
# ...                          ...   ...      ...
# 10096                west-bengal  2023        3
# 10097                west-bengal  2023        3
# 10098                west-bengal  2023        3
# 10099                west-bengal  2023        3
# 10100                west-bengal  2023        3
#
#                            District_name  Total_count  Total_amount
# 0                 south andaman district            3         795.0
# 1                      nicobars district            3         565.0
# 2      north and middle andaman district            1         281.0
# 3                 south andaman district           35       13651.0
# ...

# %%
F
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'hoverDataList': [{'name': 'south twenty four parganas district',
#     'metric': [{'type': 'TOTAL', 'count': 4100, 'amount': 5345416.0}]},
#    {'name': 'purba bardhaman district',
#     'metric': [{'type': 'TOTAL', 'count': 2444, 'amount': 3247192.0}]},
#    {'name': 'uttar dinajpur district',
#     'metric': [{'type': 'TOTAL', 'count': 916, 'amount': 1333587.0}]},
#    {'name': 'kalimpong district',
#     'metric': [{'type': 'TOTAL', 'count': 63, 'amount': 121675.0}]},
#    {'name': 'murshidabad district',
#     'metric': [{'type': 'TOTAL', 'count': 1706, 'amount': 2303518.0}]},
#    {'name': 'paschim medinipur district',
#     'metric': [{'type': 'TOTAL', 'count': 2108, 'amount': 3021797.0}]},
#    {'name': 'dakshin dinajpur district',
#     'metric': [{'type': 'TOTAL', 'count': 433, 'amount': 532754.0}]},
#    {'name': 'jalpaiguri district',
#     'metric': [{'type': 'TOTAL', 'count': 1024, 'amount': 1511512.0}]},
# ...

# %%
#Top_insurance
path7="C:/Users/vigne/Desktop/project 2/phonepe/pulse/data/top/insurance/country/india/state/"
TIL= os.listdir(path7)

columns7={"States":[], "Years":[],"Quarter":[], "District_name":[], "Total_count":[], "Total_amount":[]}

for state in TIL:
    current_state=path7+state+"/"
    AYL=os.listdir(current_state)

    for year in AYL:
        current_year=current_state+year+"/"
        AFL=os.listdir(current_year)
        
        for file in AFL:
            cursor_file=current_year+file
            data=open(cursor_file,"r")

            G=json.load(data)
            
            for i in G["data"]["districts"]:
                entityName=i["entityName"]
                count=i["metric"]["count"]
                amount=i["metric"]["amount"]
                columns7["District_name"].append(entityName)
                columns7["Total_count"].append(count)
                columns7["Total_amount"].append(amount)
                columns7["States"].append(state)
                columns7["Years"].append(year)
                columns7["Quarter"].append(int(file.strip(".json")))

# %%
top_insurance=pd.DataFrame(columns7)

# %%
top_insurance
# Out:
#                          States Years  Quarter             District_name  \
# 0     andaman-&-nicobar-islands  2020        2                  nicobars
# 1     andaman-&-nicobar-islands  2020        2             south andaman
# 2     andaman-&-nicobar-islands  2020        3             south andaman
# 3     andaman-&-nicobar-islands  2020        3                  nicobars
# 4     andaman-&-nicobar-islands  2020        3  north and middle andaman
# ...                         ...   ...      ...                       ...
# 4114                west-bengal  2023        3         paschim bardhaman
# 4115                west-bengal  2023        3           purba bardhaman
# 4116                west-bengal  2023        3                 darjiling
# 4117                west-bengal  2023        3                    maldah
# 4118                west-bengal  2023        3         paschim medinipur
#
#       Total_count  Total_amount
# 0               3         565.0
# ...

# %%
G
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'states': None,
#   'districts': [{'entityName': 'north twenty four parganas',
#     'metric': {'type': 'TOTAL', 'count': 11653, 'amount': 15397844.0}},
#    {'entityName': 'kolkata',
#     'metric': {'type': 'TOTAL', 'count': 10667, 'amount': 12579074.0}},
#    {'entityName': 'south twenty four parganas',
#     'metric': {'type': 'TOTAL', 'count': 4100, 'amount': 5345416.0}},
#    {'entityName': 'howrah',
#     'metric': {'type': 'TOTAL', 'count': 3960, 'amount': 4940209.0}},
#    {'entityName': 'hooghly',
#     'metric': {'type': 'TOTAL', 'count': 3336, 'amount': 4705529.0}},
#    {'entityName': 'paschim bardhaman',
#     'metric': {'type': 'TOTAL', 'count': 3285, 'amount': 4337285.0}},
#    {'entityName': 'purba bardhaman',
#     'metric': {'type': 'TOTAL', 'count': 2444, 'amount': 3247192.0}},
#    {'entityName': 'darjiling',
#     'metric': {'type': 'TOTAL', 'count': 2298, 'amount': 3188462.0}},
#    {'entityName': 'maldah',
# ...

# %%
#Top_transaction 
path8="C:/Users/vigne/Desktop/project 2/phonepe/pulse/data/top/transaction/country/india/state/"
TTL= os.listdir(path8)

columns8={"States":[], "Years":[],"Quarter":[], "District_name":[], "Total_count":[], "Total_amount":[]}

for state in TTL:
    current_state=path8+state+"/"
    AYL=os.listdir(current_state)

    for year in AYL:
        current_year=current_state+year+"/"
        AFL=os.listdir(current_year)
        
        for file in AFL:
            cursor_file=current_year+file
            data=open(cursor_file,"r")

            H=json.load(data)

            for i in G["data"]["districts"]:
                entityName=i["entityName"]
                count=i["metric"]["count"]
                amount=i["metric"]["amount"]
                columns8["District_name"].append(entityName)
                columns8["Total_count"].append(count)
                columns8["Total_amount"].append(amount)
                columns8["States"].append(state)
                columns8["Years"].append(year)
                columns8["Quarter"].append(int(file.strip(".json")))

# %%
top_transaction=pd.DataFrame(columns8)

# %%
top_transaction
# Out:
#                          States Years  Quarter               District_name  \
# 0     andaman-&-nicobar-islands  2018        1  north twenty four parganas
# 1     andaman-&-nicobar-islands  2018        1                     kolkata
# 2     andaman-&-nicobar-islands  2018        1  south twenty four parganas
# 3     andaman-&-nicobar-islands  2018        1                      howrah
# 4     andaman-&-nicobar-islands  2018        1                     hooghly
# ...                         ...   ...      ...                         ...
# 8275                west-bengal  2023        3           paschim bardhaman
# 8276                west-bengal  2023        3             purba bardhaman
# 8277                west-bengal  2023        3                   darjiling
# 8278                west-bengal  2023        3                      maldah
# 8279                west-bengal  2023        3           paschim medinipur
#
#       Total_count  Total_amount
# 0           11653    15397844.0
# ...

# %%
H
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'states': None,
#   'districts': [{'entityName': 'north twenty four parganas',
#     'metric': {'type': 'TOTAL', 'count': 113910456, 'amount': 166844566801.0}},
#    {'entityName': 'kolkata',
#     'metric': {'type': 'TOTAL', 'count': 80296436, 'amount': 130109928950.0}},
#    {'entityName': 'murshidabad',
#     'metric': {'type': 'TOTAL', 'count': 41360216, 'amount': 85165951696.0}},
#    {'entityName': 'south twenty four parganas',
#     'metric': {'type': 'TOTAL', 'count': 38719555, 'amount': 71124947936.0}},
#    {'entityName': 'purba medinipur',
#     'metric': {'type': 'TOTAL', 'count': 34244893, 'amount': 68137175692.0}},
#    {'entityName': 'hooghly',
#     'metric': {'type': 'TOTAL', 'count': 32021392, 'amount': 56242231460.0}},
#    {'entityName': 'howrah',
#     'metric': {'type': 'TOTAL', 'count': 31734226, 'amount': 58002367148.0}},
#    {'entityName': 'paschim bardhaman',
# ...

# %%
#Top_user
path9="C:/Users/vigne/Desktop/project 2/phonepe/pulse/data/top/user/country/india/state/"
TUL= os.listdir(path9)

columns9={"States":[], "Years":[],"Quarter":[], "District_name":[], "Registered_users":[]}


for state in TUL:
    current_state=path9+state+"/"
    AYL=os.listdir(current_state)

    for year in AYL:
        current_year=current_state+year+"/"
        AFL=os.listdir(current_year)
        
        for file in AFL:
            cursor_file=current_year+file
            data=open(cursor_file,"r")

            I=json.load(data)

            for i in I["data"]["districts"]:
                name=i["name"]
                registeredUsers=i["registeredUsers"]
                columns9["District_name"].append(name)
                columns9["Registered_users"].append(registeredUsers)
                columns9["States"].append(state)
                columns9["Years"].append(year)
                columns9["Quarter"].append(int(file.strip(".json")))

# %%
top_user=pd.DataFrame(columns9)

# %%
top_user
# Out:
#                          States Years  Quarter             District_name  \
# 0     andaman-&-nicobar-islands  2018        1             south andaman
# 1     andaman-&-nicobar-islands  2018        1  north and middle andaman
# 2     andaman-&-nicobar-islands  2018        1                  nicobars
# 3     andaman-&-nicobar-islands  2018        2             south andaman
# 4     andaman-&-nicobar-islands  2018        2  north and middle andaman
# ...                         ...   ...      ...                       ...
# 6803                west-bengal  2023        3                    howrah
# 6804                west-bengal  2023        3                     nadia
# 6805                west-bengal  2023        3           purba medinipur
# 6806                west-bengal  2023        3         paschim medinipur
# 6807                west-bengal  2023        3           purba bardhaman
#
#       Registered_users
# 0                 5846
# 1                  632
# ...

# %%
#Table_creation 
#pgsql_connection 
mydb=psycopg2.connect(host="localhost",
                      user="postgres",
                      password="Nuttertool@12",
                      database="phonepe_data",
                      port="5432"
                      )
cursor=mydb.cursor()

#aggregated insurance table 
create_query='''CREATE TABLE if not exists aggregated_insurance (States varchar(50),
                                                                    Years int,
                                                                    Quarter int,
                                                                    Transaction_type varchar (50),
                                                                    Transaction_count bigint,
                                                                    Transaction_amount bigint
                                                                    )'''

cursor.execute(create_query)
mydb.commit()

for index,row in aggre_insurance.iterrows():
    insert_query='''INSERT INTO aggregated_insurance (States, Years, Quarter, Transaction_type, Transaction_count, Transaction_amount)
                                            values(%s,%s,%s,%s,%s,%s)'''
    values=(row["States"],
            row["Years"],
            row["Quarter"],
            row["Transaction_type"],
            row["Transaction_count"],
            row["Transaction_amount"]
            )
    cursor.execute(insert_query,values)
    mydb.commit()

# %%
#aggregated transaction table 
create_query='''CREATE TABLE if not exists aggregated_transaction (States varchar(50),
                                                                    Years int,
                                                                    Quarter int,
                                                                    Transaction_type varchar (50),
                                                                    Transaction_count bigint,
                                                                    Transaction_amount bigint
                                                                    )'''

cursor.execute(create_query)
mydb.commit()

for index,row in aggre_transaction.iterrows():
    insert_query='''INSERT INTO aggregated_transaction (States, Years, Quarter, Transaction_type, Transaction_count, Transaction_amount)
                                            values(%s,%s,%s,%s,%s,%s)'''
    values=(row["States"],
            row["Years"],
            row["Quarter"],
            row["Transaction_type"],
            row["Transaction_count"],
            row["Transaction_amount"]
            )
    cursor.execute(insert_query,values)
    mydb.commit()

# %%
#aggregated user table 
create_query='''CREATE TABLE if not exists aggregated_user (States varchar(50),
                                                                    Years int,
                                                                    Quarter int,
                                                                    Device_brand varchar (50),
                                                                    Device_count bigint,
                                                                    Percentage float
                                                                    )'''

cursor.execute(create_query)
mydb.commit()

for index,row in aggre_user.iterrows():
    insert_query='''INSERT INTO aggregated_user (States, Years, Quarter, Device_brand, Device_count, Percentage)
                                            values(%s,%s,%s,%s,%s,%s)'''
    values=(row["States"],
            row["Years"],
            row["Quarter"],
            row["Device_brand"],
            row["Device_count"],
            row["Percentage"]
            )
    cursor.execute(insert_query,values)
    mydb.commit()

# %%
#map insurance table 
create_query='''CREATE TABLE if not exists map_insurance (States varchar(50),
                                                                    Years int,
                                                                    Quarter int,
                                                                    District_name varchar (50),
                                                                    Total_count bigint,
                                                                    Total_amount float
                                                                    )'''

cursor.execute(create_query)
mydb.commit()

for index,row in map_insurance.iterrows():
    insert_query='''INSERT INTO map_insurance (States, Years, Quarter, District_name, Total_count, Total_amount)
                                            values(%s,%s,%s,%s,%s,%s)'''
    values=(row["States"],
            row["Years"],
            row["Quarter"],
            row["District_name"],
            row["Total_count"],
            row["Total_amount"]
            )
    cursor.execute(insert_query,values)
    mydb.commit()

# %%
#map transaction table 
create_query='''CREATE TABLE if not exists map_transaction (States varchar(50),
                                                                    Years int,
                                                                    Quarter int,
                                                                    District_name varchar (50),
                                                                    Total_count bigint,
                                                                    Total_amount float
                                                                    )'''

cursor.execute(create_query)
mydb.commit()

for index,row in map_taransaction.iterrows():
    insert_query='''INSERT INTO map_transaction (States, Years, Quarter, District_name, Total_count, Total_amount)
                                            values(%s,%s,%s,%s,%s,%s)'''
    values=(row["States"],
            row["Years"],
            row["Quarter"],
            row["District_name"],
            row["Total_count"],
            row["Total_amount"]
            )
    cursor.execute(insert_query,values)
    mydb.commit()

# %%
#map user table
create_query='''CREATE TABLE if not exists map_user (States varchar(50),
                                                                    Years int,
                                                                    Quarter int,
                                                                    District_name varchar (50),
                                                                    RegisteredUsers bigint,
                                                                    AppOpens bigint
                                                                    )'''

cursor.execute(create_query)
mydb.commit()

for index,row in map_user.iterrows():
    insert_query='''INSERT INTO map_user (States, Years, Quarter, District_name, RegisteredUsers, AppOpens)
                                            values(%s,%s,%s,%s,%s,%s)'''
    values=(row["States"],
            row["Years"],
            row["Quarter"],
            row["District_name"],
            row["RegisteredUsers"],
            row["AppOpens"]
            )
    cursor.execute(insert_query,values)
    mydb.commit()

# %%
#top insurance table 
create_query='''CREATE TABLE if not exists top_insurance (States varchar(50),
                                                                    Years int,
                                                                    Quarter int,
                                                                    District_name varchar (50),
                                                                    Total_count bigint,
                                                                    Total_amount bigint
                                                                    )'''

cursor.execute(create_query)
mydb.commit()

for index,row in top_insurance.iterrows():
    insert_query='''INSERT INTO top_insurance (States, Years, Quarter, District_name, Total_count, Total_amount)
                                            values(%s,%s,%s,%s,%s,%s)'''
    values=(row["States"],
            row["Years"],
            row["Quarter"],
            row["District_name"],
            row["Total_count"],
            row["Total_amount"]
            )
    cursor.execute(insert_query,values)
    mydb.commit()

# %%
#top transaction table 
create_query='''CREATE TABLE if not exists top_transaction (States varchar(50),
                                                                    Years int,
                                                                    Quarter int,
                                                                    District_name varchar (50),
                                                                    Total_count bigint,
                                                                    Total_amount bigint
                                                                    )'''

cursor.execute(create_query)
mydb.commit()

for index,row in top_transaction.iterrows():
    insert_query='''INSERT INTO top_transaction (States, Years, Quarter, District_name, Total_count, Total_amount)
                                            values(%s,%s,%s,%s,%s,%s)'''
    values=(row["States"],
            row["Years"],
            row["Quarter"],
            row["District_name"],
            row["Total_count"],
            row["Total_amount"]
            )
    cursor.execute(insert_query,values)
    mydb.commit()

# %%
#top user table 
create_query='''CREATE TABLE if not exists top_user (States varchar(50),
                                                        Years int,
                                                        Quarter int,
                                                        District_name varchar (50),
                                                        Registered_users bigint
                                                        )'''

cursor.execute(create_query)
mydb.commit()

for index,row in top_user.iterrows():
    insert_query='''INSERT INTO top_user (States, Years, Quarter, District_name, Registered_users)
                                            values(%s,%s,%s,%s,%s)'''
    values=(row["States"],
            row["Years"],
            row["Quarter"],
            row["District_name"],
            row["Registered_users"]
            )
    cursor.execute(insert_query,values)
    mydb.commit()

# %%
#Create DataFrames from SQL
#Aggregated_insurance

cursor.execute("select * from aggregated_insurance;")
mydb.commit()
table1=cursor.fetchall()

Aggre_insurance=pd.DataFrame(table1,columns=("States","Years","Quarter","Transaction_type","Transaction_count","Transaction_amount"))

# %%
Aggre_insurance
# Out:
#                          States  Years  Quarter Transaction_type  \
# 0     andaman-&-nicobar-islands   2020        2        Insurance
# 1     andaman-&-nicobar-islands   2020        3        Insurance
# 2     andaman-&-nicobar-islands   2020        4        Insurance
# 3     andaman-&-nicobar-islands   2021        1        Insurance
# 4     andaman-&-nicobar-islands   2021        2        Insurance
# ...                         ...    ...      ...              ...
# 2003                west-bengal   2022        3        Insurance
# 2004                west-bengal   2022        4        Insurance
# 2005                west-bengal   2023        1        Insurance
# 2006                west-bengal   2023        2        Insurance
# 2007                west-bengal   2023        3        Insurance
#
#       Transaction_count  Transaction_amount
# 0                     6                1360
# 1                    41               15380
# 2                   124              157975
# ...

# %%
#Aggregated_transaction
cursor.execute("select * from aggregated_transaction;")
mydb.commit()
table2=cursor.fetchall()

Aggre_transaction=pd.DataFrame(table2,columns=("States","Years","Quarter","Transaction_type","Transaction_count","Transaction_amount"))

# %%
Aggre_transaction
# Out:
#                           States  Years  Quarter          Transaction_type  \
# 0      andaman-&-nicobar-islands   2018        1  Recharge & bill payments
# 1      andaman-&-nicobar-islands   2018        1     Peer-to-peer payments
# 2      andaman-&-nicobar-islands   2018        1         Merchant payments
# 3      andaman-&-nicobar-islands   2018        1        Financial Services
# 4      andaman-&-nicobar-islands   2018        1                    Others
# ...                          ...    ...      ...                       ...
# 16531                west-bengal   2023        3         Merchant payments
# 16532                west-bengal   2023        3     Peer-to-peer payments
# 16533                west-bengal   2023        3  Recharge & bill payments
# 16534                west-bengal   2023        3        Financial Services
# 16535                west-bengal   2023        3                    Others
#
#        Transaction_count  Transaction_amount
# ...

# %%
#Aggregated_user
cursor.execute("select * from aggregated_user;")
mydb.commit()
table3=cursor.fetchall()

Aggre_user=pd.DataFrame(table3,columns=("States","Years","Quarter","Device_brand","Device_count","Percentage"))

# %%
Aggre_user
# Out:
#                           States  Years  Quarter Device_brand  Device_count  \
# 0      andaman-&-nicobar-islands   2018        1       Xiaomi          1665
# 1      andaman-&-nicobar-islands   2018        1      Samsung          1445
# 2      andaman-&-nicobar-islands   2018        1         Vivo           982
# 3      andaman-&-nicobar-islands   2018        1         Oppo           501
# 4      andaman-&-nicobar-islands   2018        1      OnePlus           332
# ...                          ...    ...      ...          ...           ...
# 26923                west-bengal   2022        1       Lenovo        330017
# 26924                west-bengal   2022        1      Infinix        284678
# 26925                west-bengal   2022        1         Asus        280347
# 26926                west-bengal   2022        1        Apple        277752
# 26927                west-bengal   2022        1       Others       2196334
#
#        Percentage
# 0        0.247033
# ...

# %%
#Map_insurance
cursor.execute("select * from map_insurance;")
mydb.commit()
table4=cursor.fetchall()

Map_insurance=pd.DataFrame(table4,columns=("States","Years","Quarter","District_name","Total_count","Total_amount"))

# %%
Map_insurance
# Out:
#                           States  Years  Quarter  \
# 0      andaman-&-nicobar-islands   2020        2
# 1      andaman-&-nicobar-islands   2020        2
# 2      andaman-&-nicobar-islands   2020        3
# 3      andaman-&-nicobar-islands   2020        3
# 4      andaman-&-nicobar-islands   2020        3
# ...                          ...    ...      ...
# 40399                west-bengal   2023        3
# 40400                west-bengal   2023        3
# 40401                west-bengal   2023        3
# 40402                west-bengal   2023        3
# 40403                west-bengal   2023        3
#
#                            District_name  Total_count  Total_amount
# 0                 south andaman district            3         795.0
# 1                      nicobars district            3         565.0
# 2      north and middle andaman district            1         281.0
# 3                 south andaman district           35       13651.0
# ...

# %%
#Map_transaction
cursor.execute("select * from map_transaction;")
mydb.commit()
table5=cursor.fetchall()

Map_transaction=pd.DataFrame(table5,columns=("States","Years","Quarter","District_name","Total_count","Total_amount"))

# %%
Map_transaction
# Out:
#                           States  Years  Quarter  \
# 0      andaman-&-nicobar-islands   2018        1
# 1      andaman-&-nicobar-islands   2018        1
# 2      andaman-&-nicobar-islands   2018        1
# 3      andaman-&-nicobar-islands   2018        2
# 4      andaman-&-nicobar-islands   2018        2
# ...                          ...    ...      ...
# 67323                west-bengal   2023        3
# 67324                west-bengal   2023        3
# 67325                west-bengal   2023        3
# 67326                west-bengal   2023        3
# 67327                west-bengal   2023        3
#
#                            District_name  Total_count  Total_amount
# 0      north and middle andaman district          442  9.316631e+05
# 1                 south andaman district         5688  1.256025e+07
# 2                      nicobars district          528  1.139849e+06
# 3      north and middle andaman district          825  1.317863e+06
# ...

# %%
#Map_user
cursor.execute("select * from map_user;")
mydb.commit()
table6=cursor.fetchall()

Map_user=pd.DataFrame(table6,columns=("States","Years","Quarter","District_name","RegisteredUsers","AppOpens"))

# %%
Map_user
# Out:
#                            States  Years  Quarter  \
# 0       andaman-&-nicobar-islands   2018        1
# 1       andaman-&-nicobar-islands   2018        1
# 2       andaman-&-nicobar-islands   2018        1
# 3       andaman-&-nicobar-islands   2018        2
# 4       andaman-&-nicobar-islands   2018        2
# ...                           ...    ...      ...
# 117847                west-bengal   2023        3
# 117848                west-bengal   2023        3
# 117849                west-bengal   2023        3
# 117850                west-bengal   2023        3
# 117851                west-bengal   2023        3
#
#                                 District_name  RegisteredUsers  AppOpens
# 0       {"north and middle andaman district"}              632         0
# 1                  {"south andaman district"}             5846         0
# 2                       {"nicobars district"}              262         0
# ...

# %%
#Top_insurance
cursor.execute("select * from top_insurance;")
mydb.commit()
table7=cursor.fetchall()

Top_insurance=pd.DataFrame(table7,columns=("States","Years","Quarter","District_name","Total_count","Total_amount"))

# %%
Top_insurance
# Out:
#                           States  Years  Quarter             District_name  \
# 0      andaman-&-nicobar-islands   2020        2                  nicobars
# 1      andaman-&-nicobar-islands   2020        2             south andaman
# 2      andaman-&-nicobar-islands   2020        3             south andaman
# 3      andaman-&-nicobar-islands   2020        3                  nicobars
# 4      andaman-&-nicobar-islands   2020        3  north and middle andaman
# ...                          ...    ...      ...                       ...
# 16471                west-bengal   2023        3         paschim bardhaman
# 16472                west-bengal   2023        3           purba bardhaman
# 16473                west-bengal   2023        3                 darjiling
# 16474                west-bengal   2023        3                    maldah
# 16475                west-bengal   2023        3         paschim medinipur
#
#        Total_count  Total_amount
# 0                3           565
# ...

# %%
#Top_tansaction
cursor.execute("select * from top_transaction;")
mydb.commit()
table8=cursor.fetchall()

Top_transaction=pd.DataFrame(table8,columns=("States","Years","Quarter","District_name","Total_count","Total_amount"))

# %%
Top_transaction
# Out:
#                           States  Years  Quarter               District_name  \
# 0      andaman-&-nicobar-islands   2018        1  north twenty four parganas
# 1      andaman-&-nicobar-islands   2018        1                     kolkata
# 2      andaman-&-nicobar-islands   2018        1  south twenty four parganas
# 3      andaman-&-nicobar-islands   2018        1                      howrah
# 4      andaman-&-nicobar-islands   2018        1                     hooghly
# ...                          ...    ...      ...                         ...
# 33115                west-bengal   2023        3           paschim bardhaman
# 33116                west-bengal   2023        3             purba bardhaman
# 33117                west-bengal   2023        3                   darjiling
# 33118                west-bengal   2023        3                      maldah
# 33119                west-bengal   2023        3           paschim medinipur
#
#        Total_count  Total_amount
# ...

# %%
#Top_user
cursor.execute("select * from top_user;")
mydb.commit()
table9=cursor.fetchall()

Top_user=pd.DataFrame(table9,columns=("States","Years","Quarter","District_name","Registered_users"))

# %%
Top_user
# Out:
#                           States  Years  Quarter             District_name  \
# 0      andaman-&-nicobar-islands   2018        1             south andaman
# 1      andaman-&-nicobar-islands   2018        1  north and middle andaman
# 2      andaman-&-nicobar-islands   2018        1                  nicobars
# 3      andaman-&-nicobar-islands   2018        2             south andaman
# 4      andaman-&-nicobar-islands   2018        2  north and middle andaman
# ...                          ...    ...      ...                       ...
# 27227                west-bengal   2023        3                    howrah
# 27228                west-bengal   2023        3                     nadia
# 27229                west-bengal   2023        3           purba medinipur
# 27230                west-bengal   2023        3         paschim medinipur
# 27231                west-bengal   2023        3           purba bardhaman
#
#        Registered_users
# 0                  5846
# ...
